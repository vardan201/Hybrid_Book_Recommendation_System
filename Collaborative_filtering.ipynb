# %%
import pandas as pd
from surprise import Dataset, Reader, SVD
from surprise.model_selection import train_test_split
from surprise import accuracy

# Load the datasets
ratings = pd.read_csv("/content/ratings.csv")            # book_id, user_id, rating
books = pd.read_csv("/content/books_cleaned.csv")        # book_id, title, etc.

# -----------------------------------------
# 🧹 2. Preprocessing and Filtering
# -----------------------------------------
# Ensure correct datatypes
ratings['book_id'] = ratings['book_id'].astype(int)
books['book_id'] = books['book_id'].astype(int)
books['title'] = books['title'].astype(str).fillna('').str.lower()

# Get book_ids that appear in books.csv
valid_book_ids = set(books['book_id'].unique())

# Filter ratings to only include those for books we have metadata for
filtered_ratings = ratings[ratings['book_id'].isin(valid_book_ids)]

# Now keep only books that actually have ratings
rated_books = filtered_ratings['book_id'].value_counts()
books_with_ratings = rated_books[rated_books > 0].index
filtered_books = books[books['book_id'].isin(books_with_ratings)]
filtered_ratings = filtered_ratings[filtered_ratings['book_id'].isin(books_with_ratings)]

# %%
filtered_ratings.shape
# Out:
# (79701, 3)

# %%
filtered_books.shape
# Out:
# (812, 6)

# %%
title_to_id = filtered_books.set_index('title')['book_id'].to_dict()
id_to_title = filtered_books.set_index('book_id')['title'].to_dict()

# %%
reader = Reader(rating_scale=(filtered_ratings.rating.min(), filtered_ratings.rating.max()))
data = Dataset.load_from_df(filtered_ratings[['user_id', 'book_id', 'rating']], reader)

# %%
trainset, testset = train_test_split(data, test_size=0.2, random_state=42)

# %%
filtered_ratings.shape
# Out:
# (79701, 3)

# %%
from surprise.model_selection import GridSearchCV

param_grid = {
    'n_factors': [50, 100],
    'n_epochs': [20, 30],
    'lr_all': [0.005, 0.01],
    'reg_all': [0.02, 0.1]
}

# GridSearchCV
gs = GridSearchCV(SVD, param_grid, measures=['rmse', 'mae'], cv=3, n_jobs=-1, joblib_verbose=1)
gs.fit(data)

# Output best score and parameters
print("✅ Best RMSE:", gs.best_score['rmse'])
print("✅ Best Parameters:", gs.best_params['rmse'])

# Train final model with best parameters
best_model = gs.best_estimator['rmse']

best_model.fit(trainset)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  48 out of  48 | elapsed:   40.1s finished
# ✅ Best RMSE: 0.901051039178887
# ✅ Best Parameters: {'n_factors': 50, 'n_epochs': 30, 'lr_all': 0.01, 'reg_all': 0.1}

# %%
predictions = best_model.test(testset)
rmse = accuracy.rmse(predictions)
mae = accuracy.mae(predictions)
# Out:
# RMSE: 0.8917
# MAE:  0.7063

# %%
def get_collaborative_recommendations_by_title(book_title, top_n=10):
    book_title = book_title.lower()

    if book_title not in title_to_id:
        matched_titles = [title for title in title_to_id if book_title in title]
        if not matched_titles:
            return f"❌ Book title '{book_title}' not found in dataset."
        book_title = matched_titles[0]

    book_id = title_to_id.get(book_title)
    if book_id is None:
        return f"❌ Book title '{book_title}' not found."

    users_who_rated = filtered_ratings[filtered_ratings['book_id'] == book_id]['user_id'].unique()
    if len(users_who_rated) == 0:
        return f"⚠️ No user ratings found for the book '{book_title.title()}'"

    example_user = users_who_rated[0]

    rated_books = filtered_ratings[filtered_ratings['user_id'] == example_user]['book_id'].tolist()
    all_books = filtered_ratings['book_id'].unique()
    unrated_books = [b for b in all_books if b not in rated_books]

    predictions = [(b_id, best_model.predict(example_user, b_id).est) for b_id in unrated_books]
    top_books = sorted(predictions, key=lambda x: x[1], reverse=True)[:top_n]
    recommendations = [(id_to_title[b_id].title(), round(score, 2)) for b_id, score in top_books if b_id in id_to_title]

    return recommendations

# %%
book_name_input = "memoirs of a geisha"
recs = get_collaborative_recommendations_by_title(book_name_input, top_n=5)

print(f"\n📘 Recommendations for '{book_name_input.title()}':")
if isinstance(recs, list):
    for i, (title, rating) in enumerate(recs, 1):
        print(f"{i}. {title} (Predicted Rating: {rating})")
else:
    print(recs)
# Out:
# 📘 Recommendations for 'Memoirs Of A Geisha':
# 1. Still Life With Woodpecker (Predicted Rating: 4.76)
# 2. The Beautiful And Damned (Predicted Rating: 4.65)
# 3. Girl With A Pearl Earring (Predicted Rating: 4.64)
# 4. Peter And The Shadow Thieves (Predicted Rating: 4.62)
# 5. The Rules Of Attraction (Predicted Rating: 4.6)

# %%
filtered_books.head(30)
# Out:
#     book_id                                              title  \
# 1         3            harry potter and the philosophers stone
# 3      2657                              to kill a mockingbird
# 4      4671                                   the great gatsby
# 6      5907                 the hobbit or there and back again
# 7      5107                             the catcher in the rye
# 8       960                                      angels demons
# 9      1885                                pride and prejudice
# 12     5470                                nineteen eightyfour
# 13     7613                          animal farm a fairy story
# 17        5           harry potter and the prisoner of azkaban
# 18       34                         the fellowship of the ring
# 20        2          harry potter and the order of the phoenix
# 23        6                harry potter and the goblet of fire
# 25      968                                  the da vinci code
# 26        1              harry potter and the halfblood prince
# 27     7624                                  lord of the flies
# 31      890                                    of mice and men
# 32      930                                memoirs of a geisha
# 34      865                                       o alquimista
# 35     3636                                          the giver
# 41     1934                                       little women
# 44     4214                                         life of pi
# 47     4381                                     fahrenheit 451
# 53       11                the hitchhikers guide to the galaxy
# 54     5129                                    brave new world
# 57     2956                 the adventures of huckleberry finn
# 59     1618   the curious incident of the dog in the nighttime
# 62     6185                                  wuthering heights
# 64     4981  slaughterhousefive or the childrens crusade a ...
# 77     5139                              the devil wears prada
#
#                                   authors  goodreads_book_id  \
# 1                jk rowling mary grandpre                  3
# 3                              harper lee               2657
# 4                      f scott fitzgerald               4671
# 6                             jrr tolkien               5907
# 7                             jd salinger               5107
# 8                               dan brown                960
# 9                             jane austen               1885
# 12  george orwell erich fromm celal uster               5470
# 13                          george orwell               7613
# 17    jk rowling mary grandpre rufus beck                  5
# 18                            jrr tolkien                 34
# 20               jk rowling mary grandpre                  2
# 23               jk rowling mary grandpre                  6
# 25                              dan brown                968
# 26               jk rowling mary grandpre                  1
# 27                        william golding               7624
# 31                         john steinbeck                890
# 32                          arthur golden                930
# 34             paulo coelho alan r clarke                865
# 35                             lois lowry               3636
# 41                      louisa may alcott               1934
# 44                            yann martel               4214
# 47                           ray bradbury               4381
# 53                          douglas adams                 11
# 54                          aldous huxley               5129
# 57    mark twain john seelye guy cardwell               2956
# 59                            mark haddon               1618
# 62            emily bronte richard j dunn               6185
# 64                       kurt vonnegut jr               4981
# 77                      lauren weisberger               5139
#
#                                                  tags  \
# 1   children-s-books kindle owned-books favorite-s...
# 3   kindle owned-books harper-lee race general-fic...
# 4   owned-books america romance general-fiction no...
# 6   children-s-books on-hold kindle fiction-fantas...
# 7   owned-books america j-d-salinger general-ficti...
# 8   kindle owned-books thrillers crime-thriller cr...
# 9   on-hold kindle owned-books chick-lit austen br...
# 12  satire on-hold kindle owned-books philosophy g...
# 13  satire kindle owned-books philosophy general-f...
# 17  children-s-books kindle owned-books favorite-s...
# 18  on-hold kindle fiction-fantasy owned-books tol...
# 20  kindle fiction-fantasy owned-books romance rea...
# 23  children-s-books kindle owned-books favorite-s...
# 25  kindle owned-books thrillers crime-mystery rom...
# 26  children-s-books kindle owned-books romance fa...
# 27  kindle owned-books survival philosophy general...
# 31  kindle owned-books america general-fiction nov...
# 32  kindle owned-books japanese chick-lit wwii cul...
# 34  kindle owned-books personal-development self-i...
# 35  young-adult-literature y-a owned-books youngad...
# 41  children-s-books kindle owned-books chick-lit ...
# 44  kindle owned-books man-booker-prize survival p...
# 47  kindle owned-books books-about-books philosoph...
# 53  satire kindle hilarious owned-books novels all...
# 54  satire kindle owned-books philosophy general-f...
# 57  children-s-books satire kindle owned-books ap-...
# 59  owned-books mental-health books-to-buy to-get ...
# 62  on-hold kindle owned-books brit-lit romance ge...
# 64  satire kindle owned-books wwii kindle-unlimite...
# 77  kindle owned-books chick-lit romance womens-fi...
#
#                                               content
# 1   harry potter and the philosophers stone jk row...
# 3   to kill a mockingbird harper lee kindle owned-...
# 4   the great gatsby f scott fitzgerald owned-book...
# 6   the hobbit or there and back again jrr tolkien...
# 7   the catcher in the rye jd salinger owned-books...
# 8   angels demons dan brown kindle owned-books thr...
# 9   pride and prejudice jane austen on-hold kindle...
# 12  nineteen eightyfour george orwell erich fromm ...
# 13  animal farm a fairy story george orwell satire...
# 17  harry potter and the prisoner of azkaban jk ro...
# 18  the fellowship of the ring jrr tolkien on-hold...
# 20  harry potter and the order of the phoenix jk r...
# 23  harry potter and the goblet of fire jk rowling...
# 25  the da vinci code dan brown kindle owned-books...
# 26  harry potter and the halfblood prince jk rowli...
# 27  lord of the flies william golding kindle owned...
# 31  of mice and men john steinbeck kindle owned-bo...
# 32  memoirs of a geisha arthur golden kindle owned...
# 34  o alquimista paulo coelho alan r clarke kindle...
# 35  the giver lois lowry young-adult-literature y-...
# 41  little women louisa may alcott children-s-book...
# 44  life of pi yann martel kindle owned-books man-...
# 47  fahrenheit 451 ray bradbury kindle owned-books...
# 53  the hitchhikers guide to the galaxy douglas ad...
# 54  brave new world aldous huxley satire kindle ow...
# 57  the adventures of huckleberry finn mark twain ...
# 59  the curious incident of the dog in the nightti...
# 62  wuthering heights emily bronte richard j dunn ...
# 64  slaughterhousefive or the childrens crusade a ...
# 77  the devil wears prada lauren weisberger kindle...

# %%
popular = filtered_ratings[filtered_ratings['book_id'] == title_to_id['still life with woodpecker']]
print("Number of ratings:", popular.shape[0])
print("Average rating:", popular['rating'].mean())
# Out:
# Number of ratings: 99
# Average rating: 4.777777777777778

# %%
import pickle

# Save the trained SVD model
with open('svd_model.pkl', 'wb') as f:
    pickle.dump(best_model, f)

# %%
filtered_books.to_csv("filtered_books.csv", index=False)

# %%
filtered_ratings.to_csv("filtered_ratings.csv", index=False)

# %%
from google.colab import files
files.download('svd_model.pkl')
